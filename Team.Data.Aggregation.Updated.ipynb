# %%
import pandas as pd

#Load the data. Create new columns for defensive rebounds and the score differential 
data = pd.read_csv("nbagamestats.csv")
data["DefensiveRebounds"] = data["TotalRebounds"] - data["OffRebounds"]
data["Opp.DefensiveRebounds"] = data["Opp.TotalRebounds"] - data["Opp.OffRebounds"]
data["ScoreDiff"] = data["TeamPoints"] - data["OpponentPoints"]
ncol = data.shape[0]
nrow = data.shape[1]


#Function to get the features for a specific team
def get_team_dataframe(teamname, allteamdata):
    team_dataframe = allteamdata.loc[allteamdata['Team'] == teamname]
    return(team_dataframe)

#Index of team names 
team_index = data.Team.unique()

# %%
#Dataframes for each team, for reference. 
ATL = get_team_dataframe("ATL", data)
BOS = get_team_dataframe("BOS", data)
BRK = get_team_dataframe("BRK", data)
CHO = get_team_dataframe("CHO", data)
CHI = get_team_dataframe("CHI", data)
CLE = get_team_dataframe("CLE", data)
DAL = get_team_dataframe("DAL", data)
DEN = get_team_dataframe("DEN", data)
DET = get_team_dataframe("DET", data)
GSW = get_team_dataframe("GSW", data)
HOU = get_team_dataframe("HOU", data)
IND = get_team_dataframe("IND", data)
LAC = get_team_dataframe("LAC", data)
LAL = get_team_dataframe("LAL", data)
MEM = get_team_dataframe("MEM", data)
MIA = get_team_dataframe("MIA", data)
MIL = get_team_dataframe("MIL", data)
MIN = get_team_dataframe("MIN", data)
NOP = get_team_dataframe("NOP", data)
NYK = get_team_dataframe("NYK", data)
OKC = get_team_dataframe("OKC", data)
ORL = get_team_dataframe("ORL", data)
PHI = get_team_dataframe("PHI", data)
PHO = get_team_dataframe("PHO", data)
POR = get_team_dataframe("POR", data)
SAC = get_team_dataframe("SAC", data)
SAS = get_team_dataframe("SAS", data)
TOR = get_team_dataframe("TOR", data)
UTA = get_team_dataframe("UTA", data)
WAS = get_team_dataframe("WAS", data)

# %%
#Dictionary of the teams and their dataframes
d = {}
for name in team_index:
    d[name] = get_team_dataframe(name, data)


#Old moving average function
def team_moving_average(teamdata):
    nrow = teamdata.shape[1]
    quant_data = teamdata[["TeamPoints", "FieldGoals", "FieldGoalsAttempted", "X3PointShots", "X3PointShotsAttempted", 
              "FreeThrows", "FreeThrowsAttempted", "OffRebounds", "DefensiveRebounds", "Assists", "Steals", 
             "Blocks", "Turnovers", "TotalFouls"]]
    q = quant_data.rolling(window = 5).mean().shift(1)
    rolling_df = q.dropna()
    #date = teamdata[["Date"]][5:]
    #rolling_df = rolling_df.append(date)
    return(rolling_df)
    
    
#New moving average function 
def team_moving_average2(teamname, data):
    teamdata = get_team_dataframe(teamname, data)
    nrow = teamdata.shape[1]
    quant_data = teamdata[["FieldGoals", "FieldGoalsAttempted", "X3PointShots", "X3PointShotsAttempted", 
              "FreeThrows", "FreeThrowsAttempted", "OffRebounds", "DefensiveRebounds", "Assists", "Steals", 
             "Blocks", "Turnovers", "TotalFouls"]]
    q = quant_data.rolling(window = 10).mean().shift(1)
    opp = teamdata["Opponent"]
    date = teamdata["Date"]
    teampoints = teamdata["ScoreDiff"]
    rolling_df = q.join([opp, date, teampoints])
    return(rolling_df)

# %%
#Rolling dataframes for each team, for reference. 
ATL_R = team_moving_average2(ATL)
BOS_R = team_moving_average2(BOS)
BRK_R = team_moving_average2(BRK)
CHO_R = team_moving_average2(CHO)
CHI_R = team_moving_average2(CHI)
CLE_R = team_moving_average2(CLE)
DAL_R = team_moving_average2(DAL)
DEN_R = team_moving_average2(DEN)
DET_R = team_moving_average2(DET)
GSW_R = team_moving_average2(GSW)
HOU_R = team_moving_average2(HOU)
IND_R = team_moving_average2(IND)
LAC_R = team_moving_average2(LAC)
LAL_R = team_moving_average2(LAL)
MEM_R = team_moving_average2(MEM)
MIA_R = team_moving_average2(MIA)
MIL_R = team_moving_average2(MIL)
MIN_R = team_moving_average2(MIN)
NOP_R = team_moving_average2(NOP)
NYK_R = team_moving_average2(NYK)
OKC_R = team_moving_average2(OKC)
ORL_R = team_moving_average2(ORL)
PHI_R = team_moving_average2(PHI)
PHO_R = team_moving_average2(PHO)
POR_R = team_moving_average2(POR)
SAC_R = team_moving_average2(SAC)
SAS_R = team_moving_average2(SAS)
TOR_R = team_moving_average2(TOR)
UTA_R = team_moving_average2(UTA)
WAS_R = team_moving_average2(WAS)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-20db8e7092d1> in <module>
# ----> 1 ATL_R = team_moving_average2(ATL)
#       2 BOS_R = team_moving_average2(BOS)
#       3 BRK_R = team_moving_average2(BRK)
#       4 CHO_R = team_moving_average2(CHO)
#       5 CHI_R = team_moving_average2(CHI)
#
# TypeError: team_moving_average2() missing 1 required positional argument: 'data'

# %%
#Combined frame
data_frames = [ATL_R, BOS_R, BRK_R, CHO_R, CHI_R, CLE_R, DAL_R, DEN_R, DET_R, GSW_R, 
               HOU_R, IND_R, LAC_R, LAL_R, MEM_R, MIA_R, MIL_R, MIN_R, NOP_R, NYK_R, 
               OKC_R, ORL_R, PHI_R, PHO_R, POR_R, SAC_R, SAS_R, TOR_R, UTA_R, WAS_R]

# %%
#Unused attempt at lambda function work 
#from functools import reduce
#df_merged = reduce(lambda  left,right: pd.merge(left,right,on=["Game", "Date"],
                                            how='outer'), data_frames)

# %%
#Oponnent feature set 
quant_data_opp = teamdata[["Opp.FieldGoals", "Opp.FieldGoalsAttempted", "Opp.3PointShots", "Opp.3PointShotsAttempted", 
              "Opp.FreeThrows", "Opp.FreeThrowsAttempted", "Opp.OffRebounds", "Opp.DefensiveRebounds", "Opp.Assists", "Opp.Steals", 
             "Opp.Blocks", "Opp.Turnovers", "Opp.TotalFouls"]]

# %%
#Create final master dataframe 
complete_df = pd.DataFrame()
count = 0
for index, row in data.iterrows():
    #Identify home team, awayteam, 
    if row["Home"] == "Home":
        hometeam = row["Team"]
        awayteam = row["Opponent"]
        gamedate = row["Date"]
        leftminusright = int(row["ScoreDiff"])
        homeminusaway = leftminusright
        homedf = team_moving_average2(hometeam, data)
        awaydf = team_moving_average2(awayteam, data)
        homestats = homedf.loc[homedf["Date"] == gamedate]
        awaystats = awaydf.loc[awaydf["Date"] == gamedate]
        finalrow = pd.merge(homestats, awaystats, on = "Date", how = "left") 
        finalrow["HomeMinusAway"] = homeminusaway
        complete_df = complete_df.append(finalrow)
    if row["Home"] == "Away":
        hometeam = row["Opponent"]
        awayteam = row["Team"]
        gamedate = row["Date"]
        leftminusright = int(row["ScoreDiff"])
        homeminusaway = -leftminusright 
        homedf = team_moving_average2(hometeam, data)
        awaydf = team_moving_average2(awayteam, data)
        homestats = homedf.loc[homedf["Date"] == gamedate]
        awaystats = awaydf.loc[awaydf["Date"] == gamedate]
        finalrow = pd.merge(homestats, awaystats, on = "Date", how = "left") 
        finalrow["HomeMinusAway"] = homeminusaway
        complete_df = complete_df.append(finalrow)

# %%
#Correct number of rows 
complete_df.shape

#Drop the N/A values 
curated_df = complete_df.dropna()

# %%
#Save data to computer 
export_csv = curated_df.to_csv (r'C:\Users\zacharydiamandis\Desktop\export_dataframe3.csv', index = None, header=True)

# %%
curated_df.shape
# Out:
# (9524, 32)

# %%
complete_df
# Out:
#     FieldGoals_x  FieldGoalsAttempted_x  X3PointShots_x  \
# 0            NaN                    NaN             NaN
# 0            NaN                    NaN             NaN
# 0            NaN                    NaN             NaN
# 0            NaN                    NaN             NaN
# 0            NaN                    NaN             NaN
# 0            NaN                    NaN             NaN
# 0            NaN                    NaN             NaN
# 0            NaN                    NaN             NaN
# 0            NaN                    NaN             NaN
# 0            NaN                    NaN             NaN
# 0           37.8                   81.2             9.2
# 0           38.5                   83.6             5.2
# 0           37.7                   82.8             8.4
# 0           38.1                   81.8             8.6
# 0           37.6                   80.1             7.8
# 0           38.3                   79.5             8.1
# 0           32.1                   72.0             8.7
# 0           35.5                   83.4             6.1
# 0           39.3                   81.0             8.7
# 0           36.9                   85.8             6.5
# 0           38.8                   79.9             9.4
# 0           38.8                   81.0             9.9
# 0           35.0                   79.7             6.8
# 0           37.4                   80.5             9.9
# 0           38.6                   80.5             7.7
# 0           37.0                   86.5            10.6
# 0           41.5                   87.1            10.5
# 0           37.6                   81.2             9.9
# 0           37.5                   80.7             9.8
# 0           38.9                   78.0             7.6
# ..           ...                    ...             ...
# 0           40.6                   84.9             7.7
# 0           37.6                   79.5             9.3
# 0           40.8                   85.5            10.8
# 0           38.6                   91.1            12.0
# 0           37.2                   87.0             7.0
# 0           41.2                   84.6            13.5
# 0           42.7                   87.6            10.0
# 0           41.8                   87.2             9.1
# 0           39.3                   84.8             8.1
# 0           42.5                   86.5             9.3
# 0           41.5                   87.0             9.7
# 0           40.6                   86.7             9.9
# 0           40.0                   85.7            10.2
# 0           48.3                   98.7            10.8
# 0           41.8                   89.4            10.6
# 0           39.6                   84.5            10.0
# 0           41.6                   88.0            12.7
# 0           40.0                   85.1             9.9
# 0           40.2                   89.6             7.9
# 0           39.0                   84.1             9.8
# 0           39.2                   83.1            10.1
# 0           39.3                   83.9             9.8
# 0           39.4                   88.1            11.5
# 0           40.1                   85.0             9.0
# 0           36.3                   90.0            10.5
# 0           38.1                   87.3            15.1
# 0           41.7                   86.4            11.2
# 0           39.5                   83.3            10.1
# 0           39.0                   84.6            10.0
# 0           37.2                   89.6             8.9
#
#     X3PointShotsAttempted_x  FreeThrows_x  FreeThrowsAttempted_x  \
# 0                       NaN           NaN                    NaN
# 0                       NaN           NaN                    NaN
# 0                       NaN           NaN                    NaN
# 0                       NaN           NaN                    NaN
# 0                       NaN           NaN                    NaN
# 0                       NaN           NaN                    NaN
# 0                       NaN           NaN                    NaN
# 0                       NaN           NaN                    NaN
# 0                       NaN           NaN                    NaN
# 0                       NaN           NaN                    NaN
# 0                      24.6          17.8                   22.8
# 0                      14.9          17.0                   23.1
# 0                      25.3          18.9                   23.8
# 0                      25.2          20.2                   25.1
# 0                      23.6          20.1                   24.7
# 0                      23.7          18.6                   22.7
# 0                      23.6          18.3                   24.8
# 0                      20.5          17.3                   22.2
# 0                      24.5          17.4                   21.9
# 0                      19.8          15.5                   21.7
# 0                      24.4          17.8                   22.9
# 0                      25.0          16.9                   21.6
# 0                      19.1          13.4                   17.8
# 0                      25.7          16.2                   20.9
# 0                      22.0          19.9                   26.8
# 0                      32.8          19.4                   26.4
# 0                      27.4          17.3                   22.2
# 0                      26.2          16.1                   21.8
# 0                      25.1          17.3                   22.9
# 0                      18.5          18.0                   23.1
# ..                      ...           ...                    ...
# 0                      24.6          15.1                   19.3
# 0                      25.5          18.3                   23.2
# 0                      29.0          17.5                   21.5
# 0                      34.2          18.4                   22.6
# 0                      24.6          16.3                   21.0
# 0                      34.2          17.2                   23.4
# 0                      28.1          16.0                   18.5
# 0                      27.4          16.3                   18.8
# 0                      24.5          18.5                   23.1
# 0                      26.4          13.9                   16.7
# 0                      27.0          14.1                   17.0
# 0                      26.9          14.1                   17.4
# 0                      26.9          14.3                   17.5
# 0                      28.7          17.5                   21.7
# 0                      28.9          17.6                   24.1
# 0                      25.3          16.5                   20.3
# 0                      32.7          17.2                   21.2
# 0                      25.0          17.9                   22.9
# 0                      24.2          15.1                   19.0
# 0                      25.0          18.3                   23.4
# 0                      24.6          17.5                   22.7
# 0                      24.1          17.8                   22.9
# 0                      30.8          14.0                   18.7
# 0                      24.6          16.6                   21.6
# 0                      33.7          15.7                   20.6
# 0                      42.9          17.6                   23.2
# 0                      29.0          17.9                   22.8
# 0                      26.3          13.3                   17.0
# 0                      26.8          13.2                   17.0
# 0                      30.4          13.3                   18.7
#
#     OffRebounds_x  DefensiveRebounds_x  Assists_x  Steals_x  ...  \
# 0             NaN                  NaN        NaN       NaN  ...
# 0             NaN                  NaN        NaN       NaN  ...
# 0             NaN                  NaN        NaN       NaN  ...
# 0             NaN                  NaN        NaN       NaN  ...
# 0             NaN                  NaN        NaN       NaN  ...
# 0             NaN                  NaN        NaN       NaN  ...
# 0             NaN                  NaN        NaN       NaN  ...
# 0             NaN                  NaN        NaN       NaN  ...
# 0             NaN                  NaN        NaN       NaN  ...
# 0             NaN                  NaN        NaN       NaN  ...
# 0             9.1                 29.9       24.8       8.6  ...
# 0            11.1                 33.2       25.4       8.8  ...
# 0             9.8                 30.2       23.3       9.3  ...
# 0             9.7                 29.8       23.8       8.1  ...
# 0            10.1                 29.8       23.6       7.9  ...
# 0             9.4                 30.8       24.9       7.7  ...
# 0             7.2                 28.2       17.8       7.8  ...
# 0            10.4                 32.3       20.2       6.4  ...
# 0             8.4                 30.5       25.6       8.1  ...
# 0            11.4                 34.6       20.2       6.4  ...
# 0             7.7                 32.7       26.1       8.8  ...
# 0             8.5                 32.5       26.7       9.6  ...
# 0             8.7                 31.5       17.3       7.0  ...
# 0             7.8                 34.0       26.7       9.4  ...
# 0            11.0                 30.4       23.4       7.2  ...
# 0            13.1                 34.0       18.9       8.3  ...
# 0            11.9                 30.4       21.9       8.4  ...
# 0             7.4                 35.7       26.3       8.9  ...
# 0             7.7                 35.1       26.9       8.3  ...
# 0             7.8                 29.1       22.7       8.2  ...
# ..            ...                  ...        ...       ...  ...
# 0             7.6                 31.3       22.4      10.8  ...
# 0            10.5                 33.1       23.2       6.8  ...
# 0            10.5                 30.0       28.3       9.1  ...
# 0             9.9                 35.8       23.5       7.2  ...
# 0            10.3                 34.3       21.7       6.5  ...
# 0             6.8                 35.6       24.7       6.0  ...
# 0             9.9                 32.7       30.3       9.6  ...
# 0             9.8                 32.6       28.8       9.2  ...
# 0             9.8                 33.9       21.7       7.7  ...
# 0             9.8                 32.7       29.6       9.2  ...
# 0            10.4                 33.4       28.6       8.4  ...
# 0            11.2                 33.0       28.1       7.8  ...
# 0            10.6                 33.9       27.9       7.3  ...
# 0            10.1                 39.2       28.6       8.6  ...
# 0            11.5                 33.6       24.6      10.3  ...
# 0            10.3                 33.4       27.0       6.8  ...
# 0             9.9                 34.7       25.4       6.4  ...
# 0            11.5                 33.4       27.1       7.2  ...
# 0            10.3                 34.3       23.7       8.6  ...
# 0            11.1                 32.3       26.2       7.4  ...
# 0            10.1                 32.8       26.5       7.1  ...
# 0            10.0                 32.8       26.6       7.9  ...
# 0            10.1                 37.5       22.5       7.5  ...
# 0            10.4                 33.4       28.1       7.7  ...
# 0            12.2                 34.1       22.9       8.8  ...
# 0             9.2                 34.7       21.6       7.5  ...
# 0             9.7                 34.2       22.3       6.3  ...
# 0             9.1                 32.5       28.6       7.7  ...
# 0             9.4                 32.9       27.5       7.6  ...
# 0            10.1                 35.4       24.6       7.5  ...
#
#     OffRebounds_y  DefensiveRebounds_y  Assists_y Steals_y Blocks_y  \
# 0             NaN                  NaN        NaN      NaN      NaN
# 0             NaN                  NaN        NaN      NaN      NaN
# 0             NaN                  NaN        NaN      NaN      NaN
# 0             NaN                  NaN        NaN      NaN      NaN
# 0             NaN                  NaN        NaN      NaN      NaN
# 0             NaN                  NaN        NaN      NaN      NaN
# 0             NaN                  NaN        NaN      NaN      NaN
# 0             NaN                  NaN        NaN      NaN      NaN
# 0             NaN                  NaN        NaN      NaN      NaN
# 0            13.2                 27.6       19.6      7.6      4.1
# 0            12.3                 33.1       18.4      5.7      4.2
# 0             8.9                 30.5       24.2      8.7      4.7
# 0             8.9                 30.6       20.0      8.8      4.7
# 0             9.9                 29.3       22.7      7.8      6.1
# 0             8.7                 31.6       20.8      4.8      4.2
# 0             9.4                 31.9       25.1      7.6      3.3
# 0             8.9                 30.6       26.5      7.8      5.5
# 0             8.1                 29.8       26.7      7.9      5.2
# 0            11.8                 32.7       21.5      7.9      5.0
# 0             8.4                 31.1       25.6      8.4      4.7
# 0            12.3                 31.0       21.9     10.6      3.9
# 0             9.6                 30.4       17.7      7.7      3.4
# 0             7.8                 33.1       27.4      9.2      4.4
# 0            11.6                 35.7       22.6      5.9      5.7
# 0             7.2                 34.4       26.7      9.8      4.4
# 0             7.3                 33.9       27.2      9.3      4.4
# 0             7.3                 34.5       26.2      9.2      4.5
# 0            10.9                 30.4       25.2      8.6      4.3
# 0             8.0                 28.8       22.3      7.8      2.5
# 0             7.4                 34.9       26.3      8.2      4.9
# ..            ...                  ...        ...      ...      ...
# 0             9.9                 31.0       28.1      8.9      5.0
# 0            10.0                 30.5       27.9      8.7      4.8
# 0             8.2                 34.7       22.5      5.8      4.5
# 0            11.5                 30.2       28.0      9.9      3.9
# 0            11.3                 31.1       28.3      9.7      3.8
# 0            10.2                 32.0       29.9      9.7      4.2
# 0             9.6                 32.6       23.4      7.5      3.2
# 0            10.3                 34.9       25.9      8.6      4.4
# 0            10.1                 32.8       29.6      9.3      3.6
# 0             9.5                 35.7       31.0      7.5      7.7
# 0             7.7                 35.7       28.6      8.4      6.1
# 0            11.3                 35.2       22.2     10.2      4.9
# 0            12.4                 32.9       23.3      9.2      5.4
# 0             9.7                 33.7       27.6      6.9      4.1
# 0            10.1                 34.1       27.9      7.1      4.2
# 0             9.9                 33.4       22.1      6.5      4.3
# 0            10.8                 32.5       26.7      6.5      3.6
# 0            10.6                 32.7       18.7     10.8      3.4
# 0            11.1                 32.8       26.5      7.2      3.8
# 0             9.8                 35.3       27.4      7.6      5.1
# 0            11.1                 33.9       23.0      7.3      4.1
# 0            11.7                 34.0       22.6      7.5      5.8
# 0            10.0                 33.6       27.8      7.5      4.1
# 0            10.4                 38.2       21.2      6.7      4.2
# 0            10.5                 32.8       27.7      7.8      4.4
# 0            10.3                 32.7       28.2      7.9      4.6
# 0             9.2                 33.5       28.1      7.9      4.3
# 0             8.3                 38.7       23.2      6.5      3.2
# 0             8.6                 34.0       22.7      8.2      4.1
# 0             9.5                 34.4       28.0      7.3      4.5
#
#     Turnovers_y  TotalFouls_y  Opponent_y  ScoreDiff_y  HomeMinusAway
# 0           NaN           NaN         TOR           -7              7
# 0           NaN           NaN         ATL          -10             10
# 0           NaN           NaN         SAS           -2              2
# 0           NaN           NaN         CHO           -3              3
# 0           NaN           NaN         ATL           -7              7
# 0           NaN           NaN         NYK            6             -6
# 0           NaN           NaN         ATL           -3              3
# 0           NaN           NaN         ATL          -11             11
# 0           NaN           NaN         CLE          -33             33
# 0          12.5          23.6         ATL            5             -5
# 0          12.5          19.7         ATL          -10             10
# 0          13.5          19.0         WAS            4             -4
# 0          11.8          21.6         ATL           11            -11
# 0          10.2          22.8         ATL           -9              9
# 0           9.0          17.8         ATL          -30             30
# 0          12.7          20.0         ATL           -4              4
# 0          13.7          17.1         MIA           10            -10
# 0          13.5          18.3         BRK           23            -23
# 0          14.1          22.7         ATL          -12             12
# 0          12.6          18.8         IND           16            -16
# 0          16.7          23.1         ATL          -16             16
# 0          13.8          19.2         ATL           -6              6
# 0          13.9          17.8         ORL           -1              1
# 0          15.2          19.1         ATL           -7              7
# 0          12.7          17.6         CLE           29            -29
# 0          12.4          17.6         HOU            7             -7
# 0          12.3          17.7         DAL            3             -3
# 0          11.9          20.1         ATL           -3              3
# 0          17.6          24.1         ATL           30            -30
# 0          13.8          17.7         MIL            5             -5
# ..          ...           ...         ...          ...            ...
# 0          15.6          21.6         IND            9             -9
# 0          15.5          22.0         PHI          -13             13
# 0          12.9          21.3         WAS            6             -6
# 0          14.7          21.6         CHI           11            -11
# 0          14.7          21.3         NYK            5             -5
# 0          14.6          21.1         CLE            7             -7
# 0          11.6          16.6         WAS           17            -17
# 0          13.7          19.1         WAS          -15             15
# 0          14.2          20.9         MIL            3             -3
# 0          16.3          20.2         WAS            8             -8
# 0          10.9          20.4         WAS            7             -7
# 0          14.1          20.0         WAS            3             -3
# 0          12.7          19.1         WAS           -4              4
# 0          14.3          21.9         NOP           19            -19
# 0          14.2          21.8         MIA          -27             27
# 0          11.5          19.4         WAS            5             -5
# 0          14.7          21.6         BOS            1             -1
# 0          14.3          19.6         WAS           -7              7
# 0          14.7          21.0         SAS           -8              8
# 0          13.4          18.8         WAS            8             -8
# 0          12.7          21.5         WAS            4             -4
# 0          12.0          18.2         WAS          -10             10
# 0          14.8          19.8         DET          -11             11
# 0          11.5          15.2         WAS          -14             14
# 0          14.5          20.2         CHI          -19             19
# 0          14.6          19.4         HOU          -16             16
# 0          15.2          19.8         CLE           -4              4
# 0          14.8          16.8         WAS            6             -6
# 0          14.1          17.9         WAS          -12             12
# 0          15.4          20.1         ORL           -9              9
#
# [9840 rows x 32 columns]

# %%
 abs(int(awaystats.loc["ScoreDiff"]))
    int(awaystats["ScoreDiff"])

# %%
finalrow["HomeMinusAway"] = homeminusaway
finalrow
# Out:
#    FieldGoals_x  FieldGoalsAttempted_x  X3PointShots_x  \
# 0          39.6                   84.6            10.7
#
#    X3PointShotsAttempted_x  FreeThrows_x  FreeThrowsAttempted_x  \
# 0                     27.3          13.6                   17.4
#
#    OffRebounds_x  DefensiveRebounds_x  Assists_x  Steals_x  ...  \
# 0            9.5                 34.4       28.0       7.3  ...
#
#    OffRebounds_y  DefensiveRebounds_y  Assists_y Steals_y Blocks_y  \
# 0           10.1                 35.4       24.6      7.5      5.2
#
#    Turnovers_y  TotalFouls_y  Opponent_y  ScoreDiff_y  HomeMinusAway
# 0         11.6          16.0         WAS            9              9
#
# [1 rows x 32 columns]

# %%
leftminusright = int(row["ScoreDiff"])
homeminusaway = -leftminusright
